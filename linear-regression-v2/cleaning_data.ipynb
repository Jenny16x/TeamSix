# %%
import pandas as pd
from pathlib import Path

# %%
# read in csv as pandas dataframe
df = pd.read_csv('pitcher_salaries_cleaned.csv')
df
# Out:
#       Year         Full Name  Age    Salary   ERA  Hits  Earned Runs  \
# 0     1990         AbbottJim   23    185000  4.51   246          106
# 1     1990        AbbottPaul   23    100000  5.97    37           23
# 2     1990       AldredScott   22    100000  3.77    13            6
# 3     1990     AndersonAllan   26    300000  4.53   214           95
# 4     1990       AppierKevin   23    100000  2.76   179           57
# ...    ...               ...  ...       ...   ...   ...          ...
# 4932  2016       WorleyVance   29   2600000  3.53    84           34
# 4933  2016        WrightMike   26    510500  5.79    81           48
# 4934  2016      WrightSteven   32    514500  3.33   138           58
# 4935  2016        YoungChris   37   4250000  6.19   104           61
# 4936  2016  ZimmermannJordan   30  18000000  4.87   118           57
#
#       Strike Outs  Home Runs  Wins  Losses  Outs Pitched  \
# 0             105         16    10      14           635
# ...

# %%
# clean up column names
df=df.rename(columns={'Earned Runs':'ER','Strike Outs':'SO','Home Runs':'HR','Outs Pitched':'OP','Batters Faced by Pitcher':'BFP','Games Finished':'GF','Games Started':'GS'})
df.head()
# Out:
#    Year      Full Name  Age  Salary   ERA  Hits   ER   SO  HR  Wins  Losses  \
# 0  1990      AbbottJim   23  185000  4.51   246  106  105  16    10      14
# 1  1990     AbbottPaul   23  100000  5.97    37   23   25   0     0       5
# 2  1990    AldredScott   22  100000  3.77    13    6    7   0     1       2
# 3  1990  AndersonAllan   26  300000  4.53   214   95   82  20     7      18
# 4  1990    AppierKevin   23  100000  2.76   179   57  127  13    12       8
#
#     OP  BFP  GF  Weight  Height League Team  GS
# 0  635  925   0     200      75     AL  CAL  33
# 1  104  162   0     185      75     AL  MIN   7
# 2   43   63   0     195      76     AL  DET   3
# 3  566  797   0     178      71     AL  MIN  31
# 4  557  784   1     180      74     AL  KCA  24

# %%
# export as csv
df.to_csv('clean-col-names.csv', index=False)

# %%
# read in csv as pandas dataframe
df2 = pd.read_csv('resources/clean-col-names.csv')
df2.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23704/3629485480.py in <module>
#       1 # read in csv as pandas dataframe
# ----> 2 df2 = pd.read_csv('resources/clean-col-names.csv')
#       3 df2.head()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
