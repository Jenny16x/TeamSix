# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Files to load
file_to_load = "pitcher_salaries_cleaned.csv"

# Read the CSV into a DataFrame
pitching = pd.read_csv(file_to_load)
pitching
# Out:
#       Year         Full Name   Age      Salary   ERA  Hits  Earned Runs  \
# 0     1990         AbbottJim  23.0    185000.0  4.51   246          106
# 1     1990        AbbottPaul  23.0    100000.0  5.97    37           23
# 2     1990       AldredScott  22.0    100000.0  3.77    13            6
# 3     1990     AndersonAllan  26.0    300000.0  4.53   214           95
# 4     1990       AppierKevin  23.0    100000.0  2.76   179           57
# ...    ...               ...   ...         ...   ...   ...          ...
# 4932  2016       WorleyVance  29.0   2600000.0  3.53    84           34
# 4933  2016        WrightMike  26.0    510500.0  5.79    81           48
# 4934  2016      WrightSteven  32.0    514500.0  3.33   138           58
# 4935  2016        YoungChris  37.0   4250000.0  6.19   104           61
# 4936  2016  ZimmermannJordan  30.0  18000000.0  4.87   118           57
#
#       Strike Outs  Home Runs  Wins  Losses  Weight  Height League Team  \
# ...

# %%
x_plot = pitching["ERA"]
y_plot = pitching["Salary"]

plt.xlabel("ERA")
plt.ylabel("Salary")
plt.scatter(x_plot, y_plot)
plt.show()

# %%
x_plot = pitching["ERA"]
y_plot = pitching["Salary"]

plt.xlabel("ERA")
plt.ylabel("Salary")
plt.bar(x_plot, y_plot)
plt.show()

# %%
x_plot = pitching["Hits"]
y_plot = pitching["Salary"]

plt.xlabel("Hits")
plt.ylabel("Salary")
plt.scatter(x_plot, y_plot)
plt.show()

# %%
x_plot = pitching["Strike Outs"]
y_plot = pitching["Salary"]

plt.xlabel("Strike Outs")
plt.ylabel("Salary")
plt.scatter(x_plot, y_plot)
plt.show()

# %%
x_plot = pitching["Earned Runs"]
y_plot = pitching["Salary"]

plt.xlabel("Earned Runs")
plt.ylabel("Salary")
plt.scatter(x_plot, y_plot)
plt.show()

# %%
x_plot = pitching["Wins"]
y_plot = pitching["Salary"]

plt.xlabel("Wins")
plt.ylabel("Salary")
plt.bar(x_plot, y_plot)
plt.show()

# %%
x_plot = pitching["Losses"]
y_plot = pitching["Salary"]

plt.xlabel("Losses")
plt.ylabel("Salary")
plt.bar(x_plot, y_plot)
plt.show()

# %%
x_plot = pitching["Games Started"]
y_plot = pitching["Salary"]

plt.xlabel("Games Started")
plt.ylabel("Salary")
plt.bar(x_plot, y_plot)
plt.show()
