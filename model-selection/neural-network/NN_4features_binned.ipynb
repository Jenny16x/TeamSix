# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder, MinMaxScaler
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_csv('./resources/encoded_binned_df.csv')
df.head()
# Out:
#     ERA  Hits  Earned Runs  Strike Outs  Home Runs  Wins  Losses  \
# 0  4.51   246          106          105         16    10      14
# 1  5.97    37           23           25          0     0       5
# 2  3.77    13            6            7          0     1       2
# 3  4.53   214           95           82         20     7      18
# 4  2.76   179           57          127         13    12       8
#
#    Outs Pitched  Batters Faced by Pitcher  Games Finished  Weight  Height  \
# 0           635                       925               0     200      75
# 1           104                       162               0     185      75
# 2            43                        63               0     195      76
# 3           566                       797               0     178      71
# 4           557                       784               1     180      74
#
#    Games Started  salBin_low  salBin_mid  salBin_high  salBin_top
# 0             33           1           0            0           0
# 1              7           1           0            0           0
# 2              3           1           0            0           0
# 3             31           1           0            0           0
# 4             24           1           0            0           0

# %%
### Drop unnecessary columns
df= df.filter(['Batters Faced by Pitcher','Outs Pitched','ERA','Strike Outs',"salBin_low","salBin_mid","salBin_high","salBin_top"])
df.head()
# Out:
#    Batters Faced by Pitcher  Outs Pitched   ERA  Strike Outs  salBin_low  \
# 0                       925           635  4.51          105           1
# 1                       162           104  5.97           25           1
# 2                        63            43  3.77            7           1
# 3                       797           566  4.53           82           1
# 4                       784           557  2.76          127           1
#
#    salBin_mid  salBin_high  salBin_top
# 0           0            0           0
# 1           0            0           0
# 2           0            0           0
# 3           0            0           0
# 4           0            0           0

# %% [markdown]
# ### Split Features/Target & Training/Testing Sets
# ---
# Split into features and target
# - **y variable**: Our target variables, `Salary-Bin_low`, `Salary-Bin_mid`, `Salary-Bin_high`, `Salary-Bin_top`
# - **X variable**: Our features

# %%
# Split our preprocessed data into our features and target arrays
y = df[["salBin_low","salBin_mid","salBin_high","salBin_top"]].values
X = df.drop(["salBin_low","salBin_mid","salBin_high","salBin_top"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# C:\Users\alyss\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Build and Instantiate `StandardScaler` object, then standardize numerical features
# ---

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Build Neural Net Framework
# ---

# %%
# Define the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 128
hidden_nodes_layer2 = 64
hidden_nodes_layer3 = 24


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=4, activation="softmax"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               640
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 24)                1560
#
#  dense_3 (Dense)             (None, 4)                 100
#
# =================================================================
# Total params: 10,556
# Trainable params: 10,556
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model
# ---

# %%
# Compile the model
nn.compile(loss="kullback_leibler_divergence", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### Train the model
# ---

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 116/116 [==============================] - 0s 722us/step - loss: 4.0061 - accuracy: 0.3971
# Epoch 2/100
# 116/116 [==============================] - 0s 739us/step - loss: 1.6127 - accuracy: 0.3974
# Epoch 3/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.4097 - accuracy: 0.4155
# Epoch 4/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.3972 - accuracy: 0.4176
# Epoch 5/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.2974 - accuracy: 0.4473
# Epoch 6/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.3654 - accuracy: 0.4252
# Epoch 7/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.3648 - accuracy: 0.4373
# Epoch 8/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.3041 - accuracy: 0.4406
# Epoch 9/100
# 116/116 [==============================] - 0s 835us/step - loss: 1.3092 - accuracy: 0.4438
# Epoch 10/100
# 116/116 [==============================] - 0s 953us/step - loss: 1.3053 - accuracy: 0.4381
# Epoch 11/100
# 116/116 [==============================] - 0s 735us/step - loss: 1.4187 - accuracy: 0.4244
# Epoch 12/100
# 116/116 [==============================] - 0s 745us/step - loss: 1.2184 - accuracy: 0.4546
# Epoch 13/100
# 116/116 [==============================] - 0s 753us/step - loss: 1.2577 - accuracy: 0.4390
# Epoch 14/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.2488 - accuracy: 0.4438
# Epoch 15/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.2806 - accuracy: 0.4422
# Epoch 16/100
# 116/116 [==============================] - 0s 739us/step - loss: 1.2108 - accuracy: 0.4481
# Epoch 17/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.2272 - accuracy: 0.4446
# Epoch 18/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.2510 - accuracy: 0.4484
# Epoch 19/100
# 116/116 [==============================] - 0s 774us/step - loss: 1.2155 - accuracy: 0.4422
# Epoch 20/100
# 116/116 [==============================] - 0s 878us/step - loss: 1.2335 - accuracy: 0.4427
# Epoch 21/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.2392 - accuracy: 0.4473
# Epoch 22/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.2208 - accuracy: 0.4525
# Epoch 23/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1872 - accuracy: 0.4608
# Epoch 24/100
# 116/116 [==============================] - 0s 783us/step - loss: 1.2079 - accuracy: 0.4554
# Epoch 25/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.2007 - accuracy: 0.4419
# Epoch 26/100
# 116/116 [==============================] - 0s 774us/step - loss: 1.1837 - accuracy: 0.4619
# Epoch 27/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.2166 - accuracy: 0.4535
# Epoch 28/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1751 - accuracy: 0.4660
# Epoch 29/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1965 - accuracy: 0.4552
# Epoch 30/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1768 - accuracy: 0.4643
# Epoch 31/100
# 116/116 [==============================] - 0s 817us/step - loss: 1.1672 - accuracy: 0.4700
# Epoch 32/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1617 - accuracy: 0.4657
# Epoch 33/100
# 116/116 [==============================] - 0s 857us/step - loss: 1.1772 - accuracy: 0.4741
# Epoch 34/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1714 - accuracy: 0.4584
# Epoch 35/100
# 116/116 [==============================] - 0s 783us/step - loss: 1.1579 - accuracy: 0.4646
# Epoch 36/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1596 - accuracy: 0.4738
# Epoch 37/100
# 116/116 [==============================] - 0s 791us/step - loss: 1.1575 - accuracy: 0.4646
# Epoch 38/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1518 - accuracy: 0.4751
# Epoch 39/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1510 - accuracy: 0.4689
# Epoch 40/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1644 - accuracy: 0.4581
# Epoch 41/100
# 116/116 [==============================] - 0s 801us/step - loss: 1.1530 - accuracy: 0.4727
# Epoch 42/100
# 116/116 [==============================] - 0s 809us/step - loss: 1.1542 - accuracy: 0.4768
# Epoch 43/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1573 - accuracy: 0.4749
# Epoch 44/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1582 - accuracy: 0.4722
# Epoch 45/100
# 116/116 [==============================] - 0s 739us/step - loss: 1.1478 - accuracy: 0.4792
# Epoch 46/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1477 - accuracy: 0.4673
# Epoch 47/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1492 - accuracy: 0.4716
# Epoch 48/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1493 - accuracy: 0.4711
# Epoch 49/100
# 116/116 [==============================] - 0s 764us/step - loss: 1.1451 - accuracy: 0.4716
# Epoch 50/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1440 - accuracy: 0.4762
# Epoch 51/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1467 - accuracy: 0.4733
# Epoch 52/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1489 - accuracy: 0.4754
# Epoch 53/100
# 116/116 [==============================] - 0s 865us/step - loss: 1.1609 - accuracy: 0.4654
# Epoch 54/100
# 116/116 [==============================] - 0s 753us/step - loss: 1.1495 - accuracy: 0.4768
# Epoch 55/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1456 - accuracy: 0.4803
# Epoch 56/100
# 116/116 [==============================] - 0s 783us/step - loss: 1.1482 - accuracy: 0.4746
# Epoch 57/100
# 116/116 [==============================] - 0s 774us/step - loss: 1.1482 - accuracy: 0.4751
# Epoch 58/100
# 116/116 [==============================] - 0s 774us/step - loss: 1.1483 - accuracy: 0.4738
# Epoch 59/100
# 116/116 [==============================] - 0s 774us/step - loss: 1.1458 - accuracy: 0.4738
# Epoch 60/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1493 - accuracy: 0.4692
# Epoch 61/100
# 116/116 [==============================] - 0s 739us/step - loss: 1.1540 - accuracy: 0.4833
# Epoch 62/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1499 - accuracy: 0.4703
# Epoch 63/100
# 116/116 [==============================] - 0s 809us/step - loss: 1.1541 - accuracy: 0.4714
# Epoch 64/100
# 116/116 [==============================] - 0s 803us/step - loss: 1.1495 - accuracy: 0.4676
# Epoch 65/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1475 - accuracy: 0.4789
# Epoch 66/100
# 116/116 [==============================] - 0s 870us/step - loss: 1.1535 - accuracy: 0.4749
# Epoch 67/100
# 116/116 [==============================] - 0s 1ms/step - loss: 1.1450 - accuracy: 0.4789
# Epoch 68/100
# 116/116 [==============================] - 0s 922us/step - loss: 1.1529 - accuracy: 0.4711
# Epoch 69/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1458 - accuracy: 0.4776
# Epoch 70/100
# 116/116 [==============================] - 0s 767us/step - loss: 1.1505 - accuracy: 0.4687
# Epoch 71/100
# 116/116 [==============================] - 0s 739us/step - loss: 1.1466 - accuracy: 0.4808
# Epoch 72/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1468 - accuracy: 0.4743
# Epoch 73/100
# 116/116 [==============================] - 0s 800us/step - loss: 1.1449 - accuracy: 0.4808
# Epoch 74/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1439 - accuracy: 0.4768
# Epoch 75/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1475 - accuracy: 0.4700
# Epoch 76/100
# 116/116 [==============================] - 0s 774us/step - loss: 1.1527 - accuracy: 0.4730
# Epoch 77/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1497 - accuracy: 0.4697
# Epoch 78/100
# 116/116 [==============================] - 0s 930us/step - loss: 1.1455 - accuracy: 0.4751
# Epoch 79/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1462 - accuracy: 0.4735
# Epoch 80/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1481 - accuracy: 0.4746
# Epoch 81/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1457 - accuracy: 0.4757
# Epoch 82/100
# 116/116 [==============================] - 0s 791us/step - loss: 1.1447 - accuracy: 0.4706
# Epoch 83/100
# 116/116 [==============================] - 0s 800us/step - loss: 1.1437 - accuracy: 0.4776
# Epoch 84/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1428 - accuracy: 0.4762
# Epoch 85/100
# 116/116 [==============================] - 0s 739us/step - loss: 1.1432 - accuracy: 0.4762
# Epoch 86/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1451 - accuracy: 0.4760
# Epoch 87/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1450 - accuracy: 0.4754
# Epoch 88/100
# 116/116 [==============================] - 0s 791us/step - loss: 1.1430 - accuracy: 0.4692
# Epoch 89/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1490 - accuracy: 0.4703
# Epoch 90/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1417 - accuracy: 0.4784
# Epoch 91/100
# 116/116 [==============================] - 0s 757us/step - loss: 1.1460 - accuracy: 0.4754
# Epoch 92/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1419 - accuracy: 0.4762
# Epoch 93/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1454 - accuracy: 0.4770
# Epoch 94/100
# 116/116 [==============================] - 0s 835us/step - loss: 1.1424 - accuracy: 0.4762
# Epoch 95/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1433 - accuracy: 0.4749
# Epoch 96/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1416 - accuracy: 0.4735
# Epoch 97/100
# 116/116 [==============================] - 0s 765us/step - loss: 1.1470 - accuracy: 0.4765
# Epoch 98/100
# 116/116 [==============================] - 0s 748us/step - loss: 1.1442 - accuracy: 0.4746
# Epoch 99/100
# 116/116 [==============================] - 0s 774us/step - loss: 1.1410 - accuracy: 0.4754
# Epoch 100/100
# 116/116 [==============================] - 0s 783us/step - loss: 1.1452 - accuracy: 0.4711

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy*100:.2f}%")
# Out:
# 39/39 - 0s - loss: 1.2669 - accuracy: 0.3887 - 111ms/epoch - 3ms/step
# Loss: 1.2668801546096802, Accuracy: 38.87%

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>
