# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder, MinMaxScaler
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_csv('encoded_binned_df.csv')
df.head()
# Out:
#     ERA  Hits  Earned Runs  Strike Outs  Home Runs  Wins  Losses  \
# 0  4.51   246          106          105         16    10      14
# 1  5.97    37           23           25          0     0       5
# 2  3.77    13            6            7          0     1       2
# 3  4.53   214           95           82         20     7      18
# 4  2.76   179           57          127         13    12       8
#
#    Outs Pitched  Batters Faced by Pitcher  Games Finished  Weight  Height  \
# 0           635                       925               0     200      75
# 1           104                       162               0     185      75
# 2            43                        63               0     195      76
# 3           566                       797               0     178      71
# 4           557                       784               1     180      74
#
#    Games Started  salBin_low  salBin_mid  salBin_high  salBin_top
# 0             33           1           0            0           0
# 1              7           1           0            0           0
# 2              3           1           0            0           0
# 3             31           1           0            0           0
# 4             24           1           0            0           0

# %%
### Drop unnecessary columns
df= df.filter(['Batters Faced by Pitcher','Outs Pitched','ERA','Strike Outs',"salBin_low","salBin_mid","salBin_high","salBin_top"])
df.head()
# Out:
#    Batters Faced by Pitcher  Outs Pitched   ERA  Strike Outs  salBin_low  \
# 0                       925           635  4.51          105           1
# 1                       162           104  5.97           25           1
# 2                        63            43  3.77            7           1
# 3                       797           566  4.53           82           1
# 4                       784           557  2.76          127           1
#
#    salBin_mid  salBin_high  salBin_top
# 0           0            0           0
# 1           0            0           0
# 2           0            0           0
# 3           0            0           0
# 4           0            0           0

# %%
# scatter plot
ax = df.plot.hist(column=['ERA'], by="")

# %%
# scatter plot
plot1= df.plot.bar(x='salBin_mid',y='ERA')

# %%
# Split our preprocessed data into our features and target arrays
y = df[["salBin_low","salBin_mid","salBin_high","salBin_top"]].values
X = df.drop(["salBin_low","salBin_mid","salBin_high","salBin_top"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# C:\Users\alyss\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 12
hidden_nodes_layer2 = 12
hidden_nodes_layer3 = 4


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=4, activation="softmax"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                60
#
#  dense_1 (Dense)             (None, 12)                156
#
#  dense_2 (Dense)             (None, 4)                 52
#
#  dense_3 (Dense)             (None, 4)                 20
#
# =================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="kullback_leibler_divergence", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 116/116 [==============================] - 0s 661us/step - loss: 4.8590 - accuracy: 0.4190
# Epoch 2/100
# 116/116 [==============================] - 0s 643us/step - loss: 1.3372 - accuracy: 0.3795
# Epoch 3/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.2935 - accuracy: 0.3801
# Epoch 4/100
# 116/116 [==============================] - 0s 652us/step - loss: 1.2651 - accuracy: 0.3933
# Epoch 5/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2444 - accuracy: 0.3790
# Epoch 6/100
# 116/116 [==============================] - 0s 609us/step - loss: 1.2303 - accuracy: 0.3771
# Epoch 7/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2205 - accuracy: 0.4130
# Epoch 8/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2138 - accuracy: 0.4130
# Epoch 9/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2093 - accuracy: 0.4130
# Epoch 10/100
# 116/116 [==============================] - 0s 609us/step - loss: 1.2062 - accuracy: 0.4130
# Epoch 11/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2042 - accuracy: 0.4130
# Epoch 12/100
# 116/116 [==============================] - 0s 609us/step - loss: 1.2028 - accuracy: 0.4130
# Epoch 13/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2018 - accuracy: 0.4130
# Epoch 14/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2013 - accuracy: 0.4130
# Epoch 15/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2008 - accuracy: 0.4130
# Epoch 16/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2005 - accuracy: 0.4130
# Epoch 17/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2003 - accuracy: 0.4130
# Epoch 18/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2002 - accuracy: 0.4130
# Epoch 19/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2001 - accuracy: 0.4130
# Epoch 20/100
# 116/116 [==============================] - 0s 609us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 21/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 22/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 23/100
# 116/116 [==============================] - 0s 643us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 24/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 25/100
# 116/116 [==============================] - 0s 644us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 26/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 27/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 28/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 29/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 30/100
# 116/116 [==============================] - 0s 670us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 31/100
# 116/116 [==============================] - 0s 678us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 32/100
# 116/116 [==============================] - 0s 670us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 33/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 34/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 35/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 36/100
# 116/116 [==============================] - 0s 643us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 37/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 38/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 39/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 40/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 41/100
# 116/116 [==============================] - 0s 696us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 42/100
# 116/116 [==============================] - 0s 678us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 43/100
# 116/116 [==============================] - 0s 661us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 44/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 45/100
# 116/116 [==============================] - 0s 687us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 46/100
# 116/116 [==============================] - 0s 670us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 47/100
# 116/116 [==============================] - 0s 661us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 48/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 49/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 50/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 51/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 52/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 53/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 54/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 55/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 56/100
# 116/116 [==============================] - 0s 664us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 57/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 58/100
# 116/116 [==============================] - 0s 652us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 59/100
# 116/116 [==============================] - 0s 661us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 60/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 61/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 62/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 63/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 64/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 65/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 66/100
# 116/116 [==============================] - 0s 939us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 67/100
# 116/116 [==============================] - 0s 696us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 68/100
# 116/116 [==============================] - 0s 652us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 69/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 70/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 71/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 72/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 73/100
# 116/116 [==============================] - 0s 643us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 74/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 75/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 76/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 77/100
# 116/116 [==============================] - 0s 652us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 78/100
# 116/116 [==============================] - 0s 652us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 79/100
# 116/116 [==============================] - 0s 687us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 80/100
# 116/116 [==============================] - 0s 661us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 81/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 82/100
# 116/116 [==============================] - 0s 750us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 83/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 84/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 85/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 86/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 87/100
# 116/116 [==============================] - 0s 609us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 88/100
# 116/116 [==============================] - 0s 652us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 89/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 90/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 91/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 92/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 93/100
# 116/116 [==============================] - 0s 661us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 94/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 95/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 96/100
# 116/116 [==============================] - 0s 643us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 97/100
# 116/116 [==============================] - 0s 635us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 98/100
# 116/116 [==============================] - 0s 626us/step - loss: 1.2000 - accuracy: 0.4130
# Epoch 99/100
# 116/116 [==============================] - 0s 617us/step - loss: 1.1999 - accuracy: 0.4130
# Epoch 100/100
# 116/116 [==============================] - 0s 669us/step - loss: 1.1999 - accuracy: 0.4130

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy*100:.2f}%")
# Out:
# 39/39 - 0s - loss: 1.2003 - accuracy: 0.4219 - 109ms/epoch - 3ms/step
# Loss: 1.2003154754638672, Accuracy: 42.19%

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>
