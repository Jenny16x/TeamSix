# %%
# import dependencies
# import dependencies
import pandas as pd
from path import Path

# %%
# first import pitching stats data
data = Path('./LahmanData/People.csv')
ppl_df = pd.read_csv(data, index_col=False)
ppl_df
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0      aardsda01     1981.0        12.0      27.0          USA         CO
# 1      aaronha01     1934.0         2.0       5.0          USA         AL
# 2      aaronto01     1939.0         8.0       5.0          USA         AL
# 3       aasedo01     1954.0         9.0       8.0          USA         CA
# 4       abadan01     1972.0         8.0      25.0          USA         FL
# ...          ...        ...         ...       ...          ...        ...
# 20353   zupofr01     1939.0         8.0      29.0          USA         CA
# 20354  zuvelpa01     1958.0        10.0      31.0          USA         CA
# 20355  zuverge01     1924.0         8.0      20.0          USA         MI
# 20356  zwilldu01     1888.0        11.0       2.0          USA         MO
# 20357   zychto01     1990.0         8.0       7.0          USA         IL
#
#            birthCity  deathYear  deathMonth  deathDay  ...  nameLast  \
# ...

# %%
ppl_df.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %%
# drop unnecessary columns
ppl_df=ppl_df.drop(['birthMonth','birthDay','birthCountry','birthState','birthCity','birthYear','birthMonth', 'birthDay','birthCountry','birthState', 'birthCity','deathYear','deathMonth','deathDay','nameFirst','nameLast','nameGiven','debut','finalGame','retroID','bbrefID', 'deathCountry','deathState','deathCity'], axis=1)
ppl_df
# Out:
#         playerID  weight  height bats throws
# 0      aardsda01   215.0    75.0    R      R
# 1      aaronha01   180.0    72.0    R      R
# 2      aaronto01   190.0    75.0    R      R
# 3       aasedo01   190.0    75.0    R      R
# 4       abadan01   184.0    73.0    L      L
# ...          ...     ...     ...  ...    ...
# 20353   zupofr01   182.0    71.0    L      R
# 20354  zuvelpa01   173.0    72.0    R      R
# 20355  zuverge01   195.0    76.0    R      R
# 20356  zwilldu01   160.0    66.0    L      L
# 20357   zychto01   190.0    75.0    R      R
#
# [20358 rows x 5 columns]

# %%
# export cleaned pitching stats as csv
ppl_df.to_csv('2010-2019_people_clean.csv', index=False)
