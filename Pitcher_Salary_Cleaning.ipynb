# %%
import pandas as pd

# %%
# Files to load
file_to_load = "Resources/Pitching.csv"

# Read the CSV into a DataFrame
pitching = pd.read_csv(file_to_load)
pitching
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  WP  \
# 0      bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...  NaN   7
# 1      brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...  NaN   7
# 2      fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...  NaN   2
# 3      fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...  NaN  20
# 4      fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...  NaN   0
# ...          ...     ...    ...    ...  ...  ..  ..  ..  ..  ..  ...  ...  ..
# 48394  zeuchtj01    2020      1    TOR   AL   1   0   3   1   0  ...  0.0   0
# 48395  zimmebr02    2020      1    BAL   AL   0   0   2   1   0  ...  0.0   2
# 48396  zimmejo02    2020      1    DET   AL   0   0   3   2   0  ...  0.0   0
# 48397  zimmeky01    2020      1    KCA   AL   1   0  16   1   0  ...  0.0   2
# 48398  zuberty01    2020      1    KCA   AL   1   2  23   0   0  ...  1.0   1
#
# ...

# %%
# Files to load
file_to_load = "Resources/Salaries.csv"

# Read the CSV into a DataFrame
salaries = pd.read_csv(file_to_load)
salaries
# Out:
#        yearID teamID lgID   playerID    salary
# 0        1985    ATL   NL  barkele01    870000
# 1        1985    ATL   NL  bedrost01    550000
# 2        1985    ATL   NL  benedbr01    545000
# 3        1985    ATL   NL   campri01    633333
# 4        1985    ATL   NL  ceronri01    625000
# ...       ...    ...  ...        ...       ...
# 26423    2016    WAS   NL  strasst01  10400000
# 26424    2016    WAS   NL  taylomi02    524000
# 26425    2016    WAS   NL  treinbl01    524900
# 26426    2016    WAS   NL  werthja01  21733615
# 26427    2016    WAS   NL  zimmery01  14000000
#
# [26428 rows x 5 columns]

# %%
# Merge pitchers and salaries files
pitcher_salary = pd.merge(pitching, salaries, how='left')
pitcher_salary
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  WP  HBP  \
# 0      bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...   7  NaN
# 1      brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...   7  NaN
# 2      fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...   2  NaN
# 3      fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...  20  NaN
# 4      fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...   0  NaN
# ...          ...     ...    ...    ...  ...  ..  ..  ..  ..  ..  ...  ..  ...
# 48394  zeuchtj01    2020      1    TOR   AL   1   0   3   1   0  ...   0  0.0
# 48395  zimmebr02    2020      1    BAL   AL   0   0   2   1   0  ...   2  2.0
# 48396  zimmejo02    2020      1    DET   AL   0   0   3   2   0  ...   0  0.0
# 48397  zimmeky01    2020      1    KCA   AL   1   0  16   1   0  ...   2  1.0
# 48398  zuberty01    2020      1    KCA   AL   1   2  23   0   0  ...   1  1.0
#
# ...

# %%
pitcher_salary.dtypes
# Out:
# playerID     object
# yearID        int64
# stint         int64
# teamID       object
# lgID         object
# W             int64
# L             int64
# G             int64
# GS            int64
# CG            int64
# SHO           int64
# SV            int64
# IPouts        int64
# H             int64
# ER            int64
# HR            int64
# BB            int64
# SO            int64
# BAOpp       float64
# ERA         float64
# IBB         float64
# WP            int64
# HBP         float64
# BK            int64
# BFP         float64
# GF            int64
# R             int64
# SH          float64
# SF          float64
# GIDP        float64
# salary      float64
# dtype: object

# %%
# Filter data by years after 2000
pitcher_salary2k = pitcher_salary[pitcher_salary['yearID']>=2000]
pitcher_salary2k
# Out:
#         playerID  yearID  stint teamID lgID  W  L   G  GS  CG  ...  WP  HBP  \
# 32904  abbotpa01    2000      1    SEA   AL  9  7  35  27   0  ...   3  5.0
# 32905  aceveju01    2000      1    MIL   NL  3  7  62   0   0  ...   3  1.0
# 32906  adamste01    2000      1    LAN   NL  6  9  66   0   0  ...   5  0.0
# 32907  aguilri01    2000      1    CHN   NL  1  2  54   0   0  ...   1  4.0
# 32908  aldresc01    2000      1    PHI   NL  1  3  23   0   0  ...   1  1.0
# ...          ...     ...    ...    ...  ... .. ..  ..  ..  ..  ...  ..  ...
# 48394  zeuchtj01    2020      1    TOR   AL  1  0   3   1   0  ...   0  0.0
# 48395  zimmebr02    2020      1    BAL   AL  0  0   2   1   0  ...   2  2.0
# 48396  zimmejo02    2020      1    DET   AL  0  0   3   2   0  ...   0  0.0
# 48397  zimmeky01    2020      1    KCA   AL  1  0  16   1   0  ...   2  1.0
# 48398  zuberty01    2020      1    KCA   AL  1  2  23   0   0  ...   1  1.0
#
#        BK    BFP  GF   R   SH   SF  GIDP     salary
# ...

# %%
# Filter data by years before 2020 to avoid possible Coivd data skew 
pitcher_salary_years = pitcher_salary2k[pitcher_salary2k['yearID']<2020]
pitcher_salary_years
# Out:
#         playerID  yearID  stint teamID lgID  W   L   G  GS  CG  ...  WP  HBP  \
# 32904  abbotpa01    2000      1    SEA   AL  9   7  35  27   0  ...   3  5.0
# 32905  aceveju01    2000      1    MIL   NL  3   7  62   0   0  ...   3  1.0
# 32906  adamste01    2000      1    LAN   NL  6   9  66   0   0  ...   5  0.0
# 32907  aguilri01    2000      1    CHN   NL  1   2  54   0   0  ...   1  4.0
# 32908  aldresc01    2000      1    PHI   NL  1   3  23   0   0  ...   1  1.0
# ...          ...     ...    ...    ...  ... ..  ..  ..  ..  ..  ...  ..  ...
# 47624  zamorda01    2019      1    NYN   NL  0   1  17   0   0  ...   0  1.0
# 47625  zeuchtj01    2019      1    TOR   AL  1   2   5   3   0  ...   2  0.0
# 47626  zimmejo02    2019      1    DET   AL  1  13  23  23   0  ...   3  6.0
# 47627  zimmeky01    2019      1    KCA   AL  0   1  15   0   0  ...   2  0.0
# 47628  zobribe01    2019      1    CHN   NL  0   0   1   0   0  ...   0  0.0
#
# ...

# %%
# Filter data by pitchers who have started more than 3 games in a year 
pitcher_salary_gs = pitcher_salary_years[pitcher_salary_years['GS']>=3]
pitcher_salary_gs
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  WP  HBP  \
# 32904  abbotpa01    2000      1    SEA   AL   9   7  35  27   0  ...   3  5.0
# 32913  anderbr02    2000      1    ARI   NL  11   7  33  32   2  ...   1  3.0
# 32914  anderji02    2000      1    PIT   NL   5  11  27  26   1  ...   6  7.0
# 32917  ankieri01    2000      1    SLN   NL  11   7  31  30   0  ...  12  6.0
# 32918  appieke01    2000      1    OAK   AL  15  11  31  31   1  ...   6  9.0
# ...          ...     ...    ...    ...  ...  ..  ..  ..  ..  ..  ...  ..  ...
# 47618  yarbrry01    2019      1    TBA   AL  11   6  28  14   0  ...   0  9.0
# 47621   ynoaga01    2019      1    BAL   AL   1  10  36  13   0  ...   4  3.0
# 47623  youngal01    2019      1    ARI   NL   7   5  17  15   0  ...   2  4.0
# 47625  zeuchtj01    2019      1    TOR   AL   1   2   5   3   0  ...   2  0.0
# 47626  zimmejo02    2019      1    DET   AL   1  13  23  23   0  ...   3  6.0
#
# ...

# %%
# Drop rows without salary data
psfull = pitcher_salary_gs.dropna(subset=["salary"])
psfull
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  WP  HBP  \
# 32904  abbotpa01    2000      1    SEA   AL   9   7  35  27   0  ...   3  5.0
# 32913  anderbr02    2000      1    ARI   NL  11   7  33  32   2  ...   1  3.0
# 32914  anderji02    2000      1    PIT   NL   5  11  27  26   1  ...   6  7.0
# 32917  ankieri01    2000      1    SLN   NL  11   7  31  30   0  ...  12  6.0
# 32918  appieke01    2000      1    OAK   AL  15  11  31  31   1  ...   6  9.0
# ...          ...     ...    ...    ...  ...  ..  ..  ..  ..  ..  ...  ..  ...
# 44952  worleva01    2016      1    BAL   AL   2   2  35   4   0  ...   3  3.0
# 44955  wrighmi01    2016      1    BAL   AL   3   4  18  12   0  ...   2  9.0
# 44956  wrighst01    2016      1    BOS   AL  13   6  24  24   4  ...  10  8.0
# 44960  youngch03    2016      1    KCA   AL   3   9  34  13   0  ...   3  1.0
# 44965  zimmejo02    2016      1    DET   AL   9   7  19  18   0  ...   3  2.0
#
# ...

# %%
list(psfull.columns)
# Out:
# ['playerID',
#  'yearID',
#  'stint',
#  'teamID',
#  'lgID',
#  'W',
#  'L',
#  'G',
#  'GS',
#  'CG',
#  'SHO',
#  'SV',
#  'IPouts',
#  'H',
#  'ER',
#  'HR',
#  'BB',
#  'SO',
#  'BAOpp',
#  'ERA',
#  'IBB',
#  'WP',
#  'HBP',
#  'BK',
#  'BFP',
#  'GF',
#  'R',
#  'SH',
#  'SF',
#  'GIDP',
#  'salary']

# %%
# Drop columns not relevent 
ps_reduced = psfull.drop(["SV", "stint", "BAOpp", "IBB", "HBP", "BK", "SH", "SF", "GIDP"], 1)
ps_reduced
# Out:
#         playerID  yearID teamID lgID   W   L   G  GS  CG  SHO  ...  ER  HR  \
# 32904  abbotpa01    2000    SEA   AL   9   7  35  27   0    0  ...  84  23
# 32913  anderbr02    2000    ARI   NL  11   7  33  32   2    0  ...  96  38
# 32914  anderji02    2000    PIT   NL   5  11  27  26   1    0  ...  84  13
# 32917  ankieri01    2000    SLN   NL  11   7  31  30   0    0  ...  68  21
# 32918  appieke01    2000    OAK   AL  15  11  31  31   1    1  ...  98  23
# ...          ...     ...    ...  ...  ..  ..  ..  ..  ..  ...  ...  ..  ..
# 44952  worleva01    2016    BAL   AL   2   2  35   4   0    0  ...  34  11
# 44955  wrighmi01    2016    BAL   AL   3   4  18  12   0    0  ...  48  12
# 44956  wrighst01    2016    BOS   AL  13   6  24  24   4    1  ...  58  12
# 44960  youngch03    2016    KCA   AL   3   9  34  13   0    0  ...  61  28
# 44965  zimmejo02    2016    DET   AL   9   7  19  18   0    0  ...  57  14
#
#         BB   SO   ERA  WP    BFP  GF    R      salary
# ...

# %%
list(ps_reduced.columns)
# Out:
# ['playerID',
#  'yearID',
#  'teamID',
#  'lgID',
#  'W',
#  'L',
#  'G',
#  'GS',
#  'CG',
#  'SHO',
#  'IPouts',
#  'H',
#  'ER',
#  'HR',
#  'BB',
#  'SO',
#  'ERA',
#  'WP',
#  'BFP',
#  'GF',
#  'R',
#  'salary']

# %%
# Change columns names to full names

# %%
# Further reduce columns if needed

# %%
# Check data types using .dtypes
